# %%
#@title 🤗 AutoTrain DreamBooth
#@markdown In order to use this colab
#@markdown - upload images to a folder named `images/`
#@markdown - choose a project name if you wish
#@markdown - change model if you wish, you can also select sd2/2.1 or sd1.5
#@markdown - update prompt and remember it. choose keywords that don't usually appear in dictionaries
#@markdown - add huggingface information (token and repo_id) if you wish to push trained model to huggingface hub
#@markdown - update hyperparameters if you wish
#@markdown - click `Runtime > Run all` or run each cell individually
#@markdown - report issues / feature requests here: https://github.com/huggingface/autotrain-advanced/issues

import os
# !pip install -U autotrain-advanced > install_logs.txt
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.

# %%
#@markdown ---
#@markdown #### Project Config
project_name = 'my_dreambooth_project' # @param {type:"string"}
model_name = 'stabilityai/stable-diffusion-2-1-base' # @param ["stabilityai/stable-diffusion-xl-base-1.0", "runwayml/stable-diffusion-v1-5", "stabilityai/stable-diffusion-2-1", "stabilityai/stable-diffusion-2-1-base"]
prompt = 'photo of a isox' # @param {type: "string"}

#@markdown ---
#@markdown #### Push to Hub?
#@markdown Use these only if you want to push your trained model to a private repo in your Hugging Face Account
#@markdown If you dont use these, the model will be saved in Google Colab and you are required to download it manually.
#@markdown Please enter your Hugging Face write token. The trained model will be saved to your Hugging Face account.
#@markdown You can find your token here: https://huggingface.co/settings/tokens
push_to_hub = False # @param ["False", "True"] {type:"raw"}
hf_token = "hf_XXX" #@param {type:"string"}
repo_id = "username/repo_name" #@param {type:"string"}

#@markdown ---
#@markdown #### Hyperparameters
learning_rate = 1e-4 # @param {type:"number"}
num_steps = 100 #@param {type:"number"}
batch_size = 1 # @param {type:"slider", min:1, max:32, step:1}
gradient_accumulation = 4 # @param {type:"slider", min:1, max:32, step:1}
resolution = 1024 # @param {type:"slider", min:128, max:1024, step:128}
use_8bit_adam = False # @param ["False", "True"] {type:"raw"}
use_xformers = False # @param ["False", "True"] {type:"raw"}
use_fp16 = True # @param ["False", "True"] {type:"raw"}
train_text_encoder = False # @param ["False", "True"] {type:"raw"}
disable_gradient_checkpointing = False # @param ["False", "True"] {type:"raw"}

os.environ["PROJECT_NAME"] = project_name
os.environ["MODEL_NAME"] = model_name
os.environ["PROMPT"] = prompt
os.environ["PUSH_TO_HUB"] = str(push_to_hub)
os.environ["HF_TOKEN"] = hf_token
os.environ["REPO_ID"] = repo_id
os.environ["LEARNING_RATE"] = str(learning_rate)
os.environ["NUM_STEPS"] = str(num_steps)
os.environ["BATCH_SIZE"] = str(batch_size)
os.environ["GRADIENT_ACCUMULATION"] = str(gradient_accumulation)
os.environ["RESOLUTION"] = str(resolution)
os.environ["USE_8BIT_ADAM"] = str(use_8bit_adam)
os.environ["USE_XFORMERS"] = str(use_xformers)
os.environ["USE_FP16"] = str(use_fp16)
os.environ["TRAIN_TEXT_ENCODER"] = str(train_text_encoder)
os.environ["DISABLE_GRADIENT_CHECKPOINTING"] = str(disable_gradient_checkpointing)

# %%
MODEL_NAME
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4e291d3590d3> in <cell line: 1>()
# ----> 1 MODEL_NAME
#
# NameError: name 'MODEL_NAME' is not defined

# %%
# !autotrain dreambooth \
--model 'stabilityai/stable-diffusion-2-1-base' \
--project-name '3dhome' \
--image-path images/ \
--prompt "${PROMPT}" \
--resolution 256 \
--batch-size 1 \
--num-steps 200 \
--gradient-accumulation 4 \
--lr 0.0001 \
$( [[ "$USE_FP16" == "True" ]] && echo "--fp16" ) \
$( [[ "$USE_XFORMERS" == "True" ]] && echo "--xformers" ) \
$( [[ "$TRAIN_TEXT_ENCODER" == "True" ]] && echo "--train-text-encoder" ) \
$( [[ "$USE_8BIT_ADAM" == "True" ]] && echo "--use-8bit-adam" ) \
$( [[ "$DISABLE_GRADIENT_CHECKPOINTING" == "True" ]] && echo "--disable_gradient-checkpointing" ) \
$( [[ "$PUSH_TO_HUB" == "True" ]] && echo "--push-to-hub --token ${HF_TOKEN} --repo-id ${REPO_ID}" )
# Out:
# > INFO    Namespace(version=False, revision=None, tokenizer=None, image_path='images/', class_image_path=None, prompt='photo of a isox', class_prompt=None, num_class_images=100, class_labels_conditioning=None, prior_preservation=None, prior_loss_weight=1.0, resolution=256, center_crop=None, train_text_encoder=None, sample_batch_size=4, num_steps=200, checkpointing_steps=100000, resume_from_checkpoint=None, scale_lr=None, scheduler='constant', warmup_steps=0, num_cycles=1, lr_power=1.0, dataloader_num_workers=0, use_8bit_adam=None, adam_beta1=0.9, adam_beta2=0.999, adam_weight_decay=0.01, adam_epsilon=1e-08, max_grad_norm=1.0, allow_tf32=None, prior_generation_precision=None, local_rank=-1, xformers=None, pre_compute_text_embeddings=None, tokenizer_max_length=None, text_encoder_use_attention_mask=None, rank=4, xl=None, fp16=True, bf16=None, validation_prompt=None, num_validation_images=4, validation_epochs=50, checkpoints_total_limit=None, validation_images=None, logging=None, train=None, deploy=None, inference=None, username=None, backend='local-cli', token=None, repo_id=None, push_to_hub=None, model='stabilityai/stable-diffusion-2-1-base', project_name='3dhome', seed=42, epochs=1, gradient_accumulation=4, disable_gradient_checkpointing=None, lr=0.0001, log='none', data_path=None, train_split='train', valid_split=None, batch_size=1, func=<function run_dreambooth_command_factory at 0x7990bf3c65f0>)
# > INFO    Running DreamBooth Training
# > WARNING Parameters supplied but not used: valid_split, deploy, train_split, backend, inference, train, version, data_path, log, func
# > INFO    Dataset: 3dhome (dreambooth)
#
# > INFO    Saving concept images
# > INFO    images/isolated 48.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 145.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 44.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 36.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 5.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 88.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 77.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 137.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 156.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 12.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 113.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 62.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 94.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 84.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 53.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 119.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 70.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 3.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 79.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 68.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 108.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 29.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 122.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 159.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 39.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 49.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 96.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 6.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 54.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 134.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 14.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 107.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 31.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 58.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 59.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 1.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 139.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 9.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 158.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 73.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 76.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 19.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 111.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 43.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 118.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 45.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 21.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 15.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 140.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 22.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 7.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 26.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 157.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 131.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 109.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 71.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 33.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 92.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 93.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 162.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 130.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 123.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 153.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 121.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 151.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 27.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 25.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 110.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 161.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 0.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 24.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 129.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 30.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 136.jpg
# > INFO    Saving concept images
# > INFO    images/isolated 4.jpg
# > INFO    Starting local training...
# > INFO    {"model":"stabilityai/stable-diffusion-2-1-base","revision":null,"tokenizer":null,"image_path":"3dhome/autotrain-data","class_image_path":null,"prompt":"photo of a isox","class_prompt":null,"num_class_images":100,"class_labels_conditioning":null,"prior_preservation":false,"prior_loss_weight":1.0,"project_name":"3dhome","seed":42,"resolution":256,"center_crop":false,"train_text_encoder":false,"batch_size":1,"sample_batch_size":4,"epochs":1,"num_steps":200,"checkpointing_steps":100000,"resume_from_checkpoint":null,"gradient_accumulation":4,"disable_gradient_checkpointing":false,"lr":0.0001,"scale_lr":false,"scheduler":"constant","warmup_steps":0,"num_cycles":1,"lr_power":1.0,"dataloader_num_workers":0,"use_8bit_adam":false,"adam_beta1":0.9,"adam_beta2":0.999,"adam_weight_decay":0.01,"adam_epsilon":1e-8,"max_grad_norm":1.0,"allow_tf32":false,"prior_generation_precision":null,"local_rank":-1,"xformers":false,"pre_compute_text_embeddings":false,"tokenizer_max_length":null,"text_encoder_use_attention_mask":false,"rank":4,"xl":false,"fp16":true,"bf16":false,"token":null,"repo_id":null,"push_to_hub":false,"username":null,"validation_prompt":null,"num_validation_images":4,"validation_epochs":50,"checkpoints_total_limit":null,"validation_images":null,"logging":false}
# > INFO    ['python', '-m', 'autotrain.trainers.dreambooth', '--training_config', '3dhome/training_params.json']
# tokenizer/tokenizer_config.json: 100% 807/807 [00:00<00:00, 4.35MB/s]
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 15.1MB/s]
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 3.98MB/s]
# tokenizer/special_tokens_map.json: 100% 460/460 [00:00<00:00, 2.75MB/s]
# text_encoder/config.json: 100% 613/613 [00:00<00:00, 2.84MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# model.safetensors: 100% 1.36G/1.36G [00:05<00:00, 237MB/s]
# vae/config.json: 100% 553/553 [00:00<00:00, 3.07MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:03<00:00, 107MB/s]
# {'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# unet/config.json: 100% 911/911 [00:00<00:00, 5.07MB/s]
# diffusion_pytorch_model.safetensors: 100% 3.46G/3.46G [00:24<00:00, 141MB/s]
# {'mid_block_only_cross_attention', 'addition_embed_type', 'resnet_skip_time_act', 'addition_embed_type_num_heads', 'time_embedding_act_fn', 'encoder_hid_dim_type', 'class_embeddings_concat', 'transformer_layers_per_block', 'time_cond_proj_dim', 'projection_class_embeddings_input_dim', 'addition_time_embed_dim', 'cross_attention_norm', 'dropout', 'conv_in_kernel', 'mid_block_type', 'timestep_post_act', 'upcast_attention', 'resnet_out_scale_factor', 'class_embed_type', 'encoder_hid_dim', 'time_embedding_type', 'num_attention_heads', 'resnet_time_scale_shift', 'conv_out_kernel', 'attention_type', 'time_embedding_dim'} was not found in config. Values will be initialized to default values.
# scheduler/scheduler_config.json: 100% 346/346 [00:00<00:00, 1.87MB/s]
# {'thresholding', 'dynamic_thresholding_ratio', 'variance_type', 'timestep_spacing', 'sample_max_value', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.utils:enable_gradient_checkpointing:298 - Enabling gradient checkpointing.
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:124 - ***** Running training *****
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:125 -   Num examples = 75
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:126 -   Num batches each epoch = 75
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:127 -   Num Epochs = 11
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:128 -   Instantaneous batch size per device = 1
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:129 -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:130 -   Gradient Accumulation steps = 4
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:131 -   Total optimization steps = 200
# 🚀 INFO   | 2023-12-24 17:43:05 | autotrain.trainers.dreambooth.trainer:__init__:132 -   Training config = {'model': 'stabilityai/stable-diffusion-2-1-base', 'revision': None, 'tokenizer': None, 'image_path': '3dhome/autotrain-data/concept1', 'class_image_path': None, 'prompt': 'photo of a isox', 'class_prompt': None, 'num_class_images': 100, 'class_labels_conditioning': None, 'prior_preservation': False, 'prior_loss_weight': 1.0, 'project_name': '3dhome', 'seed': 42, 'resolution': 256, 'center_crop': False, 'train_text_encoder': False, 'batch_size': 1, 'sample_batch_size': 4, 'epochs': 11, 'num_steps': 200, 'checkpointing_steps': 100000, 'resume_from_checkpoint': None, 'gradient_accumulation': 4, 'disable_gradient_checkpointing': False, 'lr': 0.0001, 'scale_lr': False, 'scheduler': 'constant', 'warmup_steps': 0, 'num_cycles': 1, 'lr_power': 1.0, 'dataloader_num_workers': 0, 'use_8bit_adam': False, 'adam_beta1': 0.9, 'adam_beta2': 0.999, 'adam_weight_decay': 0.01, 'adam_epsilon': 1e-08, 'max_grad_norm': 1.0, 'allow_tf32': False, 'prior_generation_precision': None, 'local_rank': -1, 'xformers': False, 'pre_compute_text_embeddings': False, 'tokenizer_max_length': None, 'text_encoder_use_attention_mask': False, 'rank': 4, 'xl': False, 'fp16': True, 'bf16': False, 'token': None, 'repo_id': None, 'push_to_hub': False, 'username': None, 'validation_prompt': None, 'num_validation_images': 4, 'validation_epochs': 50, 'checkpoints_total_limit': None, 'validation_images': None, 'logging': False}
# Steps:   6% 12/200 [00:22<04:49,  1.54s/it, loss=0.0758, lr=0.0001]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q diffusers

# %%
# Inference
# this is the inference code that you can use after you have trained your model
# Unhide code below and change prj_path to your repo or local path (e.g. my_dreambooth_project)
#
#
#
from diffusers import DiffusionPipeline, StableDiffusionXLImg2ImgPipeline
import torch

prj_path = "/content/drive/MyDrive/3Dhome/3dhome"
model = "stabilityai/stable-diffusion-xl-base-1.0"
pipe = DiffusionPipeline.from_pretrained(
     model,
     torch_dtype=torch.float16,
 )
pipe.to("cuda")
pipe.load_lora_weights(prj_path, weight_name="pytorch_lora_weights.safetensors")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "isox red table photorealistic"

image = pipe(prompt=prompt).images[0]
#image = refiner(prompt=prompt, generator=generator, image=image).images[0]
image.save(f"generated_image.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
